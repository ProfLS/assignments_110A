# %% [markdown]
# # Module1-Ex3 - Getting and Knowing your Data

# %% [markdown]
# - Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries and read the dataset `chipo.csv`

# %%
import pandas as pd

df = pd.read_csv('chipo.csv')

# %% [markdown]
# ### Step 2. See the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### Step 3. What is the number of observations in the dataset?

# %%
# Solution 2
len(df)
# Out:
# 4622

# %% [markdown]
# ### Step 4. What is the number of columns in the dataset?

# %%
len(df.columns)
# Out:
# 5

# %% [markdown]
# ### Step 5. Print the name of all the columns.

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 6. How is the dataset indexed?

# %%
df.iloc[[2,5,9],[0,4]]
# Out:
#    order_id item_price
# 2         1     $3.39
# 5         3    $10.98
# 9         5     $9.25

# %% [markdown]
# ### Step 7. Which was the most-ordered item?

# %%
df.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).index[0]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 8. For the most-ordered item, how many items were ordered?

# %%
df.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).values[0]
# Out:
# 761

# %% [markdown]
# ### Step 9. What was the most ordered item in the choice_description column?

# %%
df.groupby(by='choice_description')['quantity'].sum().sort_values(ascending=False).index[0]
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### Step 10. How many items were orderd in total?

# %%
df['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### Step 11. Turn the item price into a float

# %% [markdown]
# #### Step 11.a. Check the item price type

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# #### Step 11.b. Create a lambda function and change the type of item price

# %%
price_tr = lambda price: float(price[1:])

# %%
df['item_price'] = df['item_price'].apply(price_tr)

# %% [markdown]
# #### Step 11.c. Check the item price type

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %% [markdown]
# ### Step 12. How much was the revenue for the period in the dataset?

# %%
tot_rev = (df['quantity']*df['item_price']).sum()

# %% [markdown]
# ### Step 13. How many orders were made in the period?

# %%
num_ord = df['order_id'].nunique()

# %% [markdown]
# ### Step 14. What is the average revenue amount per order?

# %%
# Solution 1
avg_rev_ord = tot_rev / num_ord
print(avg_rev_ord)
# Out:
# 21.39423118865867

# %% [markdown]
# ### Step 15. How many different items are sold?

# %%
df['item_name'].nunique()
# Out:
# 50
